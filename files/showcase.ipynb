# %% [markdown]
# # Woxi Showcase
#
# Woxi is an alternative interpreter for the Wolfram Language.
# This notebook demonstrates string manipulation, numerical capabilities, plotting features, symbolic computation, and functional programming.

# %%
StringReverse[StringJoin["Hello", " ", "world!"]]
# Out:
# !dlrow olleH

# %%
SortBy[StringSplit["A list of words"], StringLength]
# Out:
# {A, of, list, words}

# %%
GCD[2^200, 1234567892]
# Out:
# 4

# %%
N[Pi, 50]
# Out:
# 3.14159265358979323846264338327950288419716939937510582097494459230781640628619803`50.

# %%
RandomInteger[{1, 6}, 5]
# Out:
# {1, 1, 5, 4, 5}

# %%
FactorInteger[42]
# Out:
# {{2, 1}, {3, 1}, {7, 1}}

# %%
Rationalize[0.1]
# Out:
# 1/10

# %%
Plot[Sin[x], {x, -10, 10}, ImageSize -> {600, 200}]

# %%
Expand[(x + y)^6]
# Out:
# x^6 + 6*x^5*y + 15*x^4*y^2 + 20*x^3*y^3 + 15*x^2*y^4 + 6*x*y^5 + y^6

# %%
Factor[x^4 - 1]
# Out:
# (-1 + x)*(1 + x)*(1 + x^2)

# %% [markdown]
# The markdown cells support LaTeX:
#
# $\frac{x^2 - 1}{x - 1} = 1 + x$
#
# and Woxi can calculate it:

# %%
Simplify[(x^2 - 1)/(x - 1)]
# Out:
# 1 + x

# %%
D[Log[1 + t], t]
# Out:
# 1/(1 + t)

# %%
Integrate[x^2, x]
# Out:
# x^3/3

# %%
Series[Log[1 + x], {x, 0, 5}]
# Out:
# SeriesData[x, 0, {1, -1/2, 1/3, -1/4, 1/5}, 1, 6, 1]

# %%
Double[x_] := x * 2;
Double[5]
# Out:
# 10

# %%
Map[#^2 &, Range[10]]
# Out:
# {1, 4, 9, 16, 25, 36, 49, 64, 81, 100}

# %%
FoldList[#1 + #2 &, 0, Range[10]]
# Out:
# {0, 1, 3, 6, 10, 15, 21, 28, 36, 45, 55}

# %%
D[x^3 + 3 x^2 + 2 x + 1, x]
# Out:
# 2 + 3*x^2 + 6*x

# %%
Integrate[Sin[x]^2, x]
# Out:
# x/2 - Sin[2*x]/4

# %%
Solve[{2 x + y == 5, x - y == 1}, {x, y}]
# Out:
# Solve[{2*x + y == 5, x - y == 1}, {x, y}]

# %%
Clear[f];
f[0] = 1;
f[n_] := n f[n - 1];
f[6]
# Out:
# 720

# %%
FindRoot[Cos[x] == x, {x, 1}]
# Out:
# {x -> 0.7390851332151607}

# %%
StringJoin["Hello", " ", "World"]
# Out:
# Hello World

# %%
expr = a^2 + b^2 + 2 a b;
expr /. a -> x
# Out:
# 2*b*x + b^2 + x^2

# %%
Select[{apple, banana, pear, apricot}, StringMatchQ[ToString[#], "a" ~~ __] &]
# Out:
# {apple, apricot}

# %%
FullForm[(a + b)^2]
# Out:
# Power[Plus[a, b], 2]

# %%
Do[
  Print["Iteration: ", i],
  {i, 1, 5}
]
# Out:
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Null

# %%
Clear[simplify]
simplify[expr_] := expr //. {
  x_ * 1 -> x,
  1 * x_ -> x,
  x_ + 0 -> x,
  0 + x_ -> x
}

simplify[a*1 + 0 + b]
# Out:
# a + b

# %%
Context[Plot]
# Out:
# Global`

# %%
Names["Global`*"]
# Out:
# {}

# %%
lst = {a, {b, c}, d};
{Flatten[lst], Part[lst, 2, 1]}
# Out:
# {{a, b, c, d}, b}

# %%
SetAttributes[f, HoldFirst];
x = 10;
f[x] := Print["Held argument: ", x];
f[1 + 2]
# Out:
# 6

# %%
ColorNegate[Import["https://picsum.photos/256/256"]]
